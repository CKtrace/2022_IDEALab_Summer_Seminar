# %%
import numpy as np
import matplotlib.pyplot as plt

bream_length = np.array([25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 30.7, 31.0, 31.0, 
                31.5, 32.0, 32.0, 32.0, 33.0, 33.0, 33.5, 33.5, 34.0, 34.0, 34.5, 35.0, 
                35.0, 35.0, 35.0, 36.0, 36.0, 37.0, 38.5, 38.5, 39.5, 41.0, 41.0])
bream_weight = np.array([242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 450.0, 500.0, 475.0, 500.0, 
                500.0, 340.0, 600.0, 600.0, 700.0, 700.0, 610.0, 650.0, 575.0, 685.0, 620.0, 680.0, 
                700.0, 725.0, 720.0, 714.0, 850.0, 1000.0, 920.0, 955.0, 925.0, 975.0, 950.0])

# y = ax + b
a = 1
b = 0

lr = 0.0001

epochs = 100000

for i in range(epochs):
    y_pred = a * bream_length + b
    error = bream_weight - y_pred
#MAE
    for z in range(len(error)):
        if error[z] >= 1 :
            a_diff = -(1/len(bream_weight))*sum(bream_length)   
            b_diff = - 1
        else:
            a_diff = (1/len(bream_weight))*sum(bream_length)
            b_diff = 1
        

    a = a - lr * a_diff
    b = b - lr * b_diff
    
    if i % 1000 == 0:
        print("epoch = %.f, 기울기 = %.04f,  절편 or 편차 = %.04f, 에러= %.04f" %(i, a, b, error.mean()))
        print(a_diff)
        print(b_diff)
    

plt.title("MAE")
plt.scatter(bream_length, bream_weight)
plt.plot([min(bream_length), max(bream_length)], [min(y_pred), max(y_pred)], 'r')
plt.xlabel('Length')
plt.ylabel('Weight')
plt.show()
# Out:
# epoch = 0, 기울기 = 1.0033,  절편 or 편차 = 0.0001, 에러= 584.7200
# -33.10857142857142
# -1
# epoch = 1000, 기울기 = 4.3142,  절편 or 편차 = 0.1001, 에러= 475.0022
# -33.10857142857142
# -1
# epoch = 2000, 기울기 = 7.6250,  절편 or 편차 = 0.2001, 에러= 365.2845
# -33.10857142857142
# -1
# epoch = 3000, 기울기 = 10.9359,  절편 or 편차 = 0.3001, 에러= 255.5667
# -33.10857142857142
# -1
# epoch = 4000, 기울기 = 14.2467,  절편 or 편차 = 0.4001, 에러= 145.8490
# -33.10857142857142
# -1
# epoch = 5000, 기울기 = 17.5576,  절편 or 편차 = 0.5001, 에러= 36.1312
# -33.10857142857142
# -1
# epoch = 6000, 기울기 = 20.8685,  절편 or 편차 = 0.6001, 에러= -73.5865
# -33.10857142857142
# -1
# epoch = 7000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 8000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 9000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 10000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 11000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 12000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 13000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 14000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 15000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 16000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 17000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 18000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 19000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 20000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 21000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 22000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 23000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 24000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 25000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 26000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 27000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 28000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 29000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 30000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 31000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 32000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 33000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 34000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 35000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 36000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 37000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 38000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 39000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 40000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 41000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 42000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 43000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 44000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 45000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 46000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 47000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 48000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 49000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 50000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 51000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 52000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 53000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 54000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 55000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 56000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 57000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 58000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 59000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 60000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 61000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 62000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 63000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 64000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 65000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 66000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 67000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 68000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 69000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 70000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 71000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 72000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 73000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 74000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 75000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 76000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 77000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 78000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 79000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 80000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 81000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 82000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 83000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 84000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 85000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 86000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 87000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 88000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 89000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 90000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 91000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 92000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 93000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 94000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 95000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 96000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 97000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 98000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
# epoch = 99000, 기울기 = 23.1331,  절편 or 편차 = 0.6685, 에러= -148.6334
# -33.10857142857142
# -1
