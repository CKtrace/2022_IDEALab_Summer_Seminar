# %%
import torch
import matplotlib.pyplot as plt

model = torch.nn.Linear(2, 1)
optimizer = torch.optim.SGD(model.parameters(), lr=1e-2)
first_lambda = lambda epoch: 0.55 ** epoch
scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=first_lambda)

lr_adjust = []

for i in range(10):
    optimizer.step()
    lr_adjust.append(optimizer.param_groups[0]["lr"])
    scheduler.step()

print(lr_adjust)
plt.plot(range(10),lr_adjust)
# Out:
# [0.01, 0.0055000000000000005, 0.0030250000000000003, 0.0016637500000000005, 0.0009150625000000003, 0.0005032843750000001, 0.00027680640625000016, 0.0001522435234375001, 8.373393789062506e-05, 4.6053665839843786e-05]
